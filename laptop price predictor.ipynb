# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
data=pd.read_csv('laptop_data.csv')
data
# Out:
#       Unnamed: 0 Company            TypeName  Inches  \
# 0              0   Apple           Ultrabook    13.3
# 1              1   Apple           Ultrabook    13.3
# 2              2      HP            Notebook    15.6
# 3              3   Apple           Ultrabook    15.4
# 4              4   Apple           Ultrabook    13.3
# ...          ...     ...                 ...     ...
# 1298        1298  Lenovo  2 in 1 Convertible    14.0
# 1299        1299  Lenovo  2 in 1 Convertible    13.3
# 1300        1300  Lenovo            Notebook    14.0
# 1301        1301      HP            Notebook    15.6
# 1302        1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price             1303 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 122.3+ KB

# %%
data.describe()
# Out:
#        Unnamed: 0       Inches          Price
# count  1303.00000  1303.000000    1303.000000
# mean    651.00000    15.017191   59870.042910
# std     376.28801     1.426304   37243.201786
# min       0.00000    10.100000    9270.720000
# 25%     325.50000    14.000000   31914.720000
# 50%     651.00000    15.600000   52054.560000
# 75%     976.50000    15.600000   79274.246400
# max    1302.00000    18.400000  324954.720000

# %%
data.isnull().sum()
# Out:
# Unnamed: 0          0
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.drop(columns=['Unnamed: 0'],inplace=True)

# %%
data['Ram']=data['Ram'].str.replace('GB','')
data['Weight']=data['Weight'].str.replace('kg','')
data.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8            128GB SSD
# 1        Intel Core i5 1.8GHz   8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8            256GB SSD
# 3        Intel Core i7 2.7GHz  16            512GB SSD
# 4        Intel Core i5 3.1GHz   8            256GB SSD
#
#                             Gpu  OpSys Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS   1.37   71378.6832
# 1        Intel HD Graphics 6000  macOS   1.34   47895.5232
# 2         Intel HD Graphics 620  No OS   1.86   30636.0000
# ...

# %%
data['Ram']=data['Ram'].astype('int32')
data['Weight']=data['Weight'].astype('float')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float64
#  10  Price             1303 non-null   float64
# dtypes: float64(3), int32(1), object(7)
# memory usage: 107.0+ KB

# %%
sns.distplot(data['Price'])
# Out:
# C:\Users\kaif2\AppData\Local\Temp\ipykernel_16092\4196895882.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Price'])
# <Axes: xlabel='Price', ylabel='Density'>

# %%
data['Company'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Company'>

# %%
sns.barplot(x=data['Company'],y=data['Price'],palette='husl')
plt.xticks(rotation='vertical')
plt.show()
# Out:
# C:\Users\kaif2\AppData\Local\Temp\ipykernel_16092\4275463209.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=data['Company'],y=data['Price'],palette='husl')

# %%
data['TypeName'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='TypeName'>

# %%
sns.barplot(x=data['TypeName'],y=data['Price'],palette='husl')
plt.xticks(rotation='vertical')
plt.show()
# Out:
# C:\Users\kaif2\AppData\Local\Temp\ipykernel_16092\3031656129.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=data['TypeName'],y=data['Price'],palette='husl')

# %%
data['Touchscreen']=data['ScreenResolution'].apply(lambda x:1 if 'Touchscreen' in x else 0)

# %%
data.head(10)
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 5    Acer   Notebook    15.6                            1366x768
# 6   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 7   Apple  Ultrabook    13.3                            1440x900
# 8    Asus  Ultrabook    14.0                   Full HD 1920x1080
# 9    Acer  Ultrabook    14.0         IPS Panel Full HD 1920x1080
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# ...

# %%
sns.barplot(x=data['Touchscreen'],y=data['Price'],palette='Set1')
# Out:
# C:\Users\kaif2\AppData\Local\Temp\ipykernel_16092\1735342091.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=data['Touchscreen'],y=data['Price'],palette='Set1')
# <Axes: xlabel='Touchscreen', ylabel='Price'>

# %%
data['IPS']=data['ScreenResolution'].apply(lambda x:1 if 'IPS' in x else 0)
data.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# ...

# %%
sns.barplot(x=data['IPS'],y=data['Price'])
plt.show()

# %%
random=data['ScreenResolution'].str.split('x',expand=True)
random
# Out:
#                                           0     1
# 0             IPS Panel Retina Display 2560  1600
# 1                                      1440   900
# 2                              Full HD 1920  1080
# 3             IPS Panel Retina Display 2880  1800
# 4             IPS Panel Retina Display 2560  1600
# ...                                     ...   ...
# 1298   IPS Panel Full HD / Touchscreen 1920  1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200  1800
# 1300                                   1366   768
# 1301                                   1366   768
# 1302                                   1366   768
#
# [1303 rows x 2 columns]

# %%
data['x_resolution']=random[0]
data['y_resolution']=random[1]
data.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# ...

# %%
data['x_resolution']=data['x_resolution'].str.extract('(\d+)').astype('int')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\kaif2\AppData\Local\Temp\ipykernel_16092\3032706309.py:1: SyntaxWarning: invalid escape sequence '\d'
#   data['x_resolution']=data['x_resolution'].str.extract('(\d+)').astype('int')

# %%
data.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# ...

# %%
data['y_resolution']=data['y_resolution'].astype('int')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float64
#  10  Price             1303 non-null   float64
#  11  Touchscreen       1303 non-null   int64
#  12  IPS               1303 non-null   int64
#  13  x_resolution      1303 non-null   int32
#  14  y_resolution      1303 non-null   int32
# dtypes: float64(3), int32(3), int64(2), object(7)
# ...

# %%
data['PPI']=(((data['x_resolution']**2)+(data['y_resolution']**2))**0.5/data['Inches'])

# %%
data.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# ...

# %%
data.drop(columns=['ScreenResolution'],axis=1,inplace=True)

# %%
data['Cpu_name']=data['Cpu'].apply(lambda x:" ".join(x.split()[0:3]))
data.head()
# Out:
#   Company   TypeName  Inches                         Cpu  Ram  \
# 0   Apple  Ultrabook    13.3        Intel Core i5 2.3GHz    8
# 1   Apple  Ultrabook    13.3        Intel Core i5 1.8GHz    8
# 2      HP   Notebook    15.6  Intel Core i5 7200U 2.5GHz    8
# 3   Apple  Ultrabook    15.4        Intel Core i7 2.7GHz   16
# 4   Apple  Ultrabook    13.3        Intel Core i5 3.1GHz    8
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS    1.37
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS    1.34
# 2            256GB SSD         Intel HD Graphics 620  No OS    1.86
# 3            512GB SSD            AMD Radeon Pro 455  macOS    1.83
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  IPS  x_resolution  y_resolution         PPI  \
# 0   71378.6832            0    1          2560          1600  226.983005
# ...

# %%
def fetch_processor(text):
    if text=='Intel Core i7' or text=='Intel Core i5' or text=='Intel Core i3':
        return text
    else:
        if text.split()[0]=='Intel':
            return 'other intel processor'
        else:
            return 'AMD processor'

# %%
data['cpu_type']=data['Cpu_name'].apply(fetch_processor)

# %%
data.head()
# Out:
#   Company   TypeName  Inches                         Cpu  Ram  \
# 0   Apple  Ultrabook    13.3        Intel Core i5 2.3GHz    8
# 1   Apple  Ultrabook    13.3        Intel Core i5 1.8GHz    8
# 2      HP   Notebook    15.6  Intel Core i5 7200U 2.5GHz    8
# 3   Apple  Ultrabook    15.4        Intel Core i7 2.7GHz   16
# 4   Apple  Ultrabook    13.3        Intel Core i5 3.1GHz    8
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS    1.37
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS    1.34
# 2            256GB SSD         Intel HD Graphics 620  No OS    1.86
# 3            512GB SSD            AMD Radeon Pro 455  macOS    1.83
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  IPS  x_resolution  y_resolution         PPI  \
# 0   71378.6832            0    1          2560          1600  226.983005
# ...

# %%
data.drop(columns=['Cpu','Cpu_name'],inplace=True)

# %%
data['Ram'].value_counts().plot(kind='bar')
plt.show()

# %%
sns.barplot(x=data['Ram'],y=data['Price'],palette='husl')
# Out:
# C:\Users\kaif2\AppData\Local\Temp\ipykernel_16092\4281618527.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=data['Ram'],y=data['Price'],palette='husl')
# <Axes: xlabel='Ram', ylabel='Price'>

# %%
data['Memory'].unique()
# Out:
# array(['128GB SSD', '128GB Flash Storage', '256GB SSD', '512GB SSD',
#        '500GB HDD', '256GB Flash Storage', '1TB HDD',
#        '32GB Flash Storage', '128GB SSD +  1TB HDD',
#        '256GB SSD +  256GB SSD', '64GB Flash Storage',
#        '256GB SSD +  1TB HDD', '256GB SSD +  2TB HDD', '32GB SSD',
#        '2TB HDD', '64GB SSD', '1.0TB Hybrid', '512GB SSD +  1TB HDD',
#        '1TB SSD', '256GB SSD +  500GB HDD', '128GB SSD +  2TB HDD',
#        '512GB SSD +  512GB SSD', '16GB SSD', '16GB Flash Storage',
#        '512GB SSD +  256GB SSD', '512GB SSD +  2TB HDD',
#        '64GB Flash Storage +  1TB HDD', '180GB SSD', '1TB HDD +  1TB HDD',
#        '32GB HDD', '1TB SSD +  1TB HDD', '512GB Flash Storage',
#        '128GB HDD', '240GB SSD', '8GB SSD', '508GB Hybrid', '1.0TB HDD',
#        '512GB SSD +  1.0TB Hybrid', '256GB SSD +  1.0TB Hybrid'],
#       dtype=object)

# %%
data['Memory'].value_counts()
# Out:
# Memory
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# ...

# %%
data.head()
# Out:
#   Company   TypeName  Inches  Ram               Memory  \
# 0   Apple  Ultrabook    13.3    8            128GB SSD
# 1   Apple  Ultrabook    13.3    8  128GB Flash Storage
# 2      HP   Notebook    15.6    8            256GB SSD
# 3   Apple  Ultrabook    15.4   16            512GB SSD
# 4   Apple  Ultrabook    13.3    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#    x_resolution  y_resolution         PPI       cpu_type
# 0          2560          1600  226.983005  Intel Core i5
# ...

# %%
data.drop(columns=['SSD','HDD','Hybrid','Flash_Storage'],inplace=True)

# %%
# Step 1: Ensure Memory is a string and standardize units
data['Memory'] = data['Memory'].astype(str).replace('\.0', '', regex=True)
data['Memory'] = data['Memory'].str.replace('GB', '')
data['Memory'] = data['Memory'].str.replace('TB', '000')  # Convert TB to GB

# Step 2: Split Memory into two parts (in case of +)
new = data["Memory"].str.split("+", n=1, expand=True)
data["first"] = new[0].str.strip()
data["second"] = new[1].fillna("0").str.strip()

# Step 3: Detect storage types (BEFORE removing text)
data["Layer1HDD"] = data["first"].str.contains("HDD", case=False).astype(int)
data["Layer1SSD"] = data["first"].str.contains("SSD", case=False).astype(int)
data["Layer1Hybrid"] = data["first"].str.contains("Hybrid", case=False).astype(int)
data["Layer1Flash_Storage"] = data["first"].str.contains("Flash Storage", case=False).astype(int)

data["Layer2HDD"] = data["second"].str.contains("HDD", case=False).astype(int)
data["Layer2SSD"] = data["second"].str.contains("SSD", case=False).astype(int)
data["Layer2Hybrid"] = data["second"].str.contains("Hybrid", case=False).astype(int)
data["Layer2Flash_Storage"] = data["second"].str.contains("Flash Storage", case=False).astype(int)

# Step 4: Extract just the numbers (GB values)
data['first'] = data['first'].str.replace(r'\D', '', regex=True)
data['second'] = data['second'].str.replace(r'\D', '', regex=True)

# Step 5: Convert to integers
data["first"] = data["first"].astype(int)
data["second"] = data["second"].astype(int)

# Step 6: Calculate actual storage in each category
data["HDD"] = data["first"] * data["Layer1HDD"] + data["second"] * data["Layer2HDD"]
data["SSD"] = data["first"] * data["Layer1SSD"] + data["second"] * data["Layer2SSD"]
data["Hybrid"] = data["first"] * data["Layer1Hybrid"] + data["second"] * data["Layer2Hybrid"]
data["Flash_Storage"] = data["first"] * data["Layer1Flash_Storage"] + data["second"] * data["Layer2Flash_Storage"]

# Step 7: Drop helper columns
data.drop(columns=[
    'first', 'second', 'Layer1HDD', 'Layer1SSD', 'Layer1Hybrid',
    'Layer1Flash_Storage', 'Layer2HDD', 'Layer2SSD', 'Layer2Hybrid',
    'Layer2Flash_Storage'
], inplace=True)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\.'
# <>:2: SyntaxWarning: invalid escape sequence '\.'
# C:\Users\kaif2\AppData\Local\Temp\ipykernel_16092\2965947769.py:2: SyntaxWarning: invalid escape sequence '\.'
#   data['Memory'] = data['Memory'].astype(str).replace('\.0', '', regex=True)

# %%
data.head()
# Out:
#   Company   TypeName  Inches  Ram             Memory  \
# 0   Apple  Ultrabook    13.3    8            128 SSD
# 1   Apple  Ultrabook    13.3    8  128 Flash Storage
# 2      HP   Notebook    15.6    8            256 SSD
# 3   Apple  Ultrabook    15.4   16            512 SSD
# 4   Apple  Ultrabook    13.3    8            256 SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#    x_resolution  y_resolution         PPI       cpu_type  HDD  SSD  Hybrid  \
# 0          2560          1600  226.983005  Intel Core i5    0  128       0
# ...

# %%
data.sample()
# Out:
#     Company TypeName  Inches  Ram               Memory  \
# 367  Lenovo   Gaming    15.6    8  128 SSD +  1000 HDD
#
#                          Gpu  OpSys  Weight     Price  Touchscreen  IPS  \
# 367  Nvidia GeForce GTX 1050  No OS     2.4  43103.52            0    1
#
#      x_resolution  y_resolution         PPI       cpu_type   HDD  SSD  Hybrid  \
# 367          1920          1080  141.211998  Intel Core i5  1000  128       0
#
#      Flash_Storage
# 367              0

# %%
data.drop(columns=['Memory'],inplace=True)

# %%
data.head()
# Out:
#   Company   TypeName  Inches  Ram                           Gpu  OpSys  \
# 0   Apple  Ultrabook    13.3    8  Intel Iris Plus Graphics 640  macOS
# 1   Apple  Ultrabook    13.3    8        Intel HD Graphics 6000  macOS
# 2      HP   Notebook    15.6    8         Intel HD Graphics 620  No OS
# 3   Apple  Ultrabook    15.4   16            AMD Radeon Pro 455  macOS
# 4   Apple  Ultrabook    13.3    8  Intel Iris Plus Graphics 650  macOS
#
#    Weight        Price  Touchscreen  IPS  x_resolution  y_resolution  \
# 0    1.37   71378.6832            0    1          2560          1600
# 1    1.34   47895.5232            0    0          1440           900
# 2    1.86   30636.0000            0    0          1920          1080
# 3    1.83  135195.3360            0    1          2880          1800
# 4    1.37   96095.8080            0    1          2560          1600
#
#           PPI       cpu_type  HDD  SSD  Hybrid  Flash_Storage
# ...

# %%
numeric_data = data.select_dtypes(include=['int','float','int64', 'float64'])
correlation=numeric_data.corr()['Price']
correlation
# Out:
# Inches           0.068197
# Ram              0.743007
# Weight           0.210370
# Price            1.000000
# Touchscreen      0.191226
# IPS              0.252208
# x_resolution     0.083832
# y_resolution     0.552809
# PPI              0.348331
# HDD             -0.096441
# SSD              0.670799
# Hybrid           0.007989
# Flash_Storage   -0.040511
# Name: Price, dtype: float64

# %%
data.drop(columns=['Hybrid','Flash_Storage'],inplace=True)

# %%
data['Gpu_brand']=data['Gpu'].apply(lambda x:x.split()[0])
data.head()
# Out:
#   Company   TypeName  Inches  Ram                           Gpu  OpSys  \
# 0   Apple  Ultrabook    13.3    8  Intel Iris Plus Graphics 640  macOS
# 1   Apple  Ultrabook    13.3    8        Intel HD Graphics 6000  macOS
# 2      HP   Notebook    15.6    8         Intel HD Graphics 620  No OS
# 3   Apple  Ultrabook    15.4   16            AMD Radeon Pro 455  macOS
# 4   Apple  Ultrabook    13.3    8  Intel Iris Plus Graphics 650  macOS
#
#    Weight        Price  Touchscreen  IPS  x_resolution  y_resolution  \
# 0    1.37   71378.6832            0    1          2560          1600
# 1    1.34   47895.5232            0    0          1440           900
# 2    1.86   30636.0000            0    0          1920          1080
# 3    1.83  135195.3360            0    1          2880          1800
# 4    1.37   96095.8080            0    1          2560          1600
#
#           PPI       cpu_type  HDD  SSD Gpu_brand
# 0  226.983005  Intel Core i5    0  128     Intel
# ...

# %%
data=data[data['Gpu_brand']!='ARM']

# %%
data.head()
# Out:
#   Company   TypeName  Inches  Ram                           Gpu  OpSys  \
# 0   Apple  Ultrabook    13.3    8  Intel Iris Plus Graphics 640  macOS
# 1   Apple  Ultrabook    13.3    8        Intel HD Graphics 6000  macOS
# 2      HP   Notebook    15.6    8         Intel HD Graphics 620  No OS
# 3   Apple  Ultrabook    15.4   16            AMD Radeon Pro 455  macOS
# 4   Apple  Ultrabook    13.3    8  Intel Iris Plus Graphics 650  macOS
#
#    Weight        Price  Touchscreen  IPS  x_resolution  y_resolution  \
# 0    1.37   71378.6832            0    1          2560          1600
# 1    1.34   47895.5232            0    0          1440           900
# 2    1.86   30636.0000            0    0          1920          1080
# 3    1.83  135195.3360            0    1          2880          1800
# 4    1.37   96095.8080            0    1          2560          1600
#
#           PPI       cpu_type  HDD  SSD Gpu_brand
# 0  226.983005  Intel Core i5    0  128     Intel
# ...

# %%
sns.barplot(x=data['Gpu_brand'],y=data['Price'],palette='husl')
plt.xticks(rotation='vertical')
plt.show()
# Out:
# C:\Users\kaif2\AppData\Local\Temp\ipykernel_16092\911835997.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=data['Gpu_brand'],y=data['Price'],palette='husl')

# %%
data.drop(columns=['Gpu'],inplace=True)
# Out:
# C:\Users\kaif2\AppData\Local\Temp\ipykernel_16092\2462585147.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop(columns=['Gpu'],inplace=True)

# %%
data['OpSys'].value_counts()
# Out:
# OpSys
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: count, dtype: int64

# %%
def opsystem(input):
    if input=='Windows 10' or input=='Windows 7' or input=='Windows 10 S ':
        return 'Windows'
    else:
        if input=='macOS' or input=='Mac OS X':
            return 'Mac'
        else:
            return 'others'

# %%
data['operating_sys']=data['OpSys'].apply(opsystem)
data.head()
# Out:
# C:\Users\kaif2\AppData\Local\Temp\ipykernel_16092\613442979.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['operating_sys']=data['OpSys'].apply(opsystem)
#   Company   TypeName  Inches  Ram  OpSys  Weight        Price  Touchscreen  \
# 0   Apple  Ultrabook    13.3    8  macOS    1.37   71378.6832            0
# 1   Apple  Ultrabook    13.3    8  macOS    1.34   47895.5232            0
# 2      HP   Notebook    15.6    8  No OS    1.86   30636.0000            0
# 3   Apple  Ultrabook    15.4   16  macOS    1.83  135195.3360            0
# 4   Apple  Ultrabook    13.3    8  macOS    1.37   96095.8080            0
#
#    IPS  x_resolution  y_resolution         PPI       cpu_type  HDD  SSD  \
# ...

# %%
data.drop(columns=['Inches','OpSys','x_resolution',	'y_resolution'],inplace=True)
# Out:
# C:\Users\kaif2\AppData\Local\Temp\ipykernel_16092\1909875155.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop(columns=['Inches','OpSys','x_resolution',	'y_resolution'],inplace=True)

# %%
data.head()
# Out:
#   Company   TypeName  Ram  Weight        Price  Touchscreen  IPS         PPI  \
# 0   Apple  Ultrabook    8    1.37   71378.6832            0    1  226.983005
# 1   Apple  Ultrabook    8    1.34   47895.5232            0    0  127.677940
# 2      HP   Notebook    8    1.86   30636.0000            0    0  141.211998
# 3   Apple  Ultrabook   16    1.83  135195.3360            0    1  220.534624
# 4   Apple  Ultrabook    8    1.37   96095.8080            0    1  226.983005
#
#         cpu_type  HDD  SSD Gpu_brand operating_sys
# 0  Intel Core i5    0  128     Intel           Mac
# 1  Intel Core i5    0    0     Intel           Mac
# 2  Intel Core i5    0  256     Intel        others
# 3  Intel Core i7    0  512       AMD           Mac
# 4  Intel Core i5    0  256     Intel           Mac

# %%
x=data.drop(columns=['Price'])
y=np.log(data['Price'])

# %%
x
# Out:
#      Company            TypeName  Ram  Weight  Touchscreen  IPS         PPI  \
# 0      Apple           Ultrabook    8    1.37            0    1  226.983005
# 1      Apple           Ultrabook    8    1.34            0    0  127.677940
# 2         HP            Notebook    8    1.86            0    0  141.211998
# 3      Apple           Ultrabook   16    1.83            0    1  220.534624
# 4      Apple           Ultrabook    8    1.37            0    1  226.983005
# ...      ...                 ...  ...     ...          ...  ...         ...
# 1298  Lenovo  2 in 1 Convertible    4    1.80            1    1  157.350512
# 1299  Lenovo  2 in 1 Convertible   16    1.30            1    1  276.053530
# 1300  Lenovo            Notebook    2    1.50            0    0  111.935204
# 1301      HP            Notebook    6    2.19            0    0  100.454670
# 1302    Asus            Notebook    4    2.20            0    0  100.454670
#
# ...

# %%
y
# Out:
# 0       11.175755
# 1       10.776777
# 2       10.329931
# 3       11.814476
# 4       11.473101
#           ...
# 1298    10.433899
# 1299    11.288115
# 1300     9.409283
# 1301    10.614129
# 1302     9.886358
# Name: Price, Length: 1302, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score,mean_absolute_error

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = RandomForestRegressor(n_estimators=100,
                              random_state=3,
                              max_samples=0.5,
                              max_features=0.75,
                              max_depth=15)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(x_train,y_train)

y_pred = pipe.predict(x_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8722710488842995
# MAE 0.16084906154810505

# %%
import pickle

pickle.dump(data,open('df.pkl','wb'))
pickle.dump(pipe,open('pipe.pkl','wb'))
